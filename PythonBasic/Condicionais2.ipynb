# %%
#Outro exemplo de condicionais

temp = int(input("Entre com a temperatura: "))

if 0 <= temp <= 10:
  print("Muito frio!!")
elif 20 <= temp <= 25:
  print("Temperatura ambiente")
elif 26 <= temp <= 35:
  print("Quente")
else:
  print("Muito quente!!!")
# Out:
# Entre com a temperatura: 32
# Quente
