# %%
#Conversão de dados com Python
#Python realiza as conversões automaticamente, de forma implícita

n = 5
print(n)
n = 5.5
print(n)
n = "Seis"
print(n)

n1 = 3
n2 = 4.5
n1 += n2 #recebe o acréscimo do valor real
print(n1)

texto = str(65)
texto += str(62.5) #Concatenação
print(texto)
# Out:
# 5
# 5.5
# Seis
# 7.5
# 6562.5
