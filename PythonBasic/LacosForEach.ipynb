# %%
#Trabalhando com loops for each

dados = {"Rex": ["Biscoito", "Ração", "Água"], "Fifi":["Ração", "Água"]}

for i in dados.keys():
  print(f"O que o {i} comeu pela última vez: ")
  for j in dados[i]:
    print(j)
# Out:
# O que o Rex comeu pela última vez:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-a08946e1cb32> in <cell line: 6>()
#       6 for i in dados.keys():
#       7   print(f"O que o {i} comeu pela última vez: ")
# ----> 8   for j in dados[dogs]:
#       9     print(j)
#
# TypeError: unhashable type: 'list'
